# %%
#Import of data as CSV
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from google.colab import drive

# %%
df = pd.read_csv('passenger_data.csv',encoding = "utf-8")

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
# Drop the column Nr 1
df = df.drop(df.columns[[0]], axis=1)

# %%
# Capitalise the column names 'id' and 'satisfaction'
df.rename(columns={'id': 'ID', 'satisfaction': 'Satisfaction'}, inplace=True)

# %%
# Capitalise 'disloyal' in the column Nr 3 and "travel" in column Nr 5
df['Customer Type'] = df['Customer Type'].str.replace('disloyal', 'Disloyal')
df['Type of Travel']= df['Type of Travel'].str.replace ('Business travel', 'Business Travel' )

# %%
# Show null values (true= no value)
nullvalues = df.isnull()
print(nullvalues)
# Out:
#            ID  Gender  Customer Type    Age  Type of Travel  Class  \
# 0       False   False          False  False           False  False
# 1       False   False          False  False           False  False
# 2       False   False          False  False           False  False
# 3       False   False          False  False           False  False
# 4       False   False          False  False           False  False
# ...       ...     ...            ...    ...             ...    ...
# 103919  False   False          False  False           False  False
# 103920  False   False          False  False           False  False
# 103921  False   False          False  False           False  False
# 103922  False   False          False  False           False  False
# 103923  False   False          False  False           False  False
#
#         Flight Distance  Inflight wifi service  \
# 0                 False                  False
# 1                 False                  False
# 2                 False                  False
# 3                 False                  False
# 4                 False                  False
# ...                 ...                    ...
# 103919            False                  False
# 103920            False                  False
# 103921            False                  False
# 103922            False                  False
# 103923            False                  False
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                   False                   False  ...
# 1                                   False                   False  ...
# 2                                   False                   False  ...
# 3                                   False                   False  ...
# 4                                   False                   False  ...
# ...                                   ...                     ...  ...
# 103919                              False                   False  ...
# 103920                              False                   False  ...
# 103921                              False                   False  ...
# 103922                              False                   False  ...
# 103923                              False                   False  ...
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                        False             False             False
# 1                        False             False             False
# 2                        False             False             False
# 3                        False             False             False
# 4                        False             False             False
# ...                        ...               ...               ...
# 103919                   False             False             False
# 103920                   False             False             False
# 103921                   False             False             False
# 103922                   False             False             False
# 103923                   False             False             False
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                  False            False             False        False
# 1                  False            False             False        False
# 2                  False            False             False        False
# 3                  False            False             False        False
# 4                  False            False             False        False
# ...                  ...              ...               ...          ...
# 103919             False            False             False        False
# 103920             False            False             False        False
# 103921             False            False             False        False
# 103922             False            False             False        False
# 103923             False            False             False        False
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  Satisfaction
# 0                            False                     False         False
# 1                            False                     False         False
# 2                            False                     False         False
# 3                            False                     False         False
# 4                            False                     False         False
# ...                            ...                       ...           ...
# 103919                       False                     False         False
# 103920                       False                     False         False
# 103921                       False                     False         False
# 103922                       False                     False         False
# 103923                       False                     False         False
#
# [103924 rows x 24 columns]

# %%
# Count of how many null values there are in each column
nullvalues = df.isnull().sum()
print(nullvalues)
# Out:
# ID                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# Satisfaction                           0
# dtype: int64

# %% [markdown]
# # The data is complete for all columns except for "Arrival delay in minutes" where 310 out of 103923 values are missing. As this does not represent a very large number and information on arrival delay is probably important to assess customer satisfaction, we decided to drop the rows containing null values and to only use complete data for our model.

# %%
# Drop null values
df_new = df.copy()
df_new = df.dropna()

# %%
# New data frame (df_new) has no null values
df_new.isnull().sum()
# Out:
# ID                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# Satisfaction                         0
# dtype: int64

# %%
# Transform column "Arrival Delay in Minutes" in integer numbers
df = df.fillna(0)
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].astype(int)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103614 entries, 0 to 103923
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ID                                 103614 non-null  int64
#  1   Gender                             103614 non-null  object
#  2   Customer Type                      103614 non-null  object
#  3   Age                                103614 non-null  int64
#  4   Type of Travel                     103614 non-null  object
#  5   Class                              103614 non-null  object
#  6   Flight Distance                    103614 non-null  int64
#  7   Inflight wifi service              103614 non-null  int64
#  8   Departure/Arrival time convenient  103614 non-null  int64
#  9   Ease of Online booking             103614 non-null  int64
#  10  Gate location                      103614 non-null  int64
#  11  Food and drink                     103614 non-null  int64
#  12  Online boarding                    103614 non-null  int64
#  13  Seat comfort                       103614 non-null  int64
#  14  Inflight entertainment             103614 non-null  int64
#  15  On-board service                   103614 non-null  int64
#  16  Leg room service                   103614 non-null  int64
#  17  Baggage handling                   103614 non-null  int64
#  18  Checkin service                    103614 non-null  int64
#  19  Inflight service                   103614 non-null  int64
#  20  Cleanliness                        103614 non-null  int64
#  21  Departure Delay in Minutes         103614 non-null  int64
#  22  Arrival Delay in Minutes           103614 non-null  float64
#  23  Satisfaction                       103614 non-null  object
# dtypes: float64(1), int64(18), object(5)
# memory usage: 19.8+ MB

# %%
df_new.describe()
# Out:
#                   ID            Age  Flight Distance  Inflight wifi service  \
# count  103614.000000  103614.000000    103614.000000          103614.000000
# mean    64943.326336      39.379794      1189.278736               2.729786
# std     37460.794345      15.113194       997.272823               1.327819
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32562.250000      27.000000       414.000000               2.000000
# 50%     64894.500000      40.000000       842.000000               3.000000
# 75%     97370.500000      51.000000      1742.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103614.000000           103614.000000
# mean                            3.060137                2.756992
# std                             1.525226                1.398941
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  103614.000000   103614.000000    103614.000000  103614.000000
# mean        2.977020        3.202135         3.250478       3.439690
# std         1.277739        1.329352         1.349420       1.318842
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           103614.000000     103614.000000     103614.000000
# mean                 3.358282          3.382632          3.351304
# std                  1.333006          1.288292          1.315464
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     103614.000000    103614.000000     103614.000000  103614.000000
# mean           3.631691         3.304264          3.640772       3.286293
# std            1.181087         1.265411          1.175622       1.312190
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               103614.000000             103614.000000
# mean                    14.745826                 15.176414
# std                     38.113593                 38.695437
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
##Data Analysis
Let's have a look at how many customers are satisfied (or not).

# %%
df_new.groupby('Satisfaction').count()
# Out:
#                             ID  Gender  Customer Type    Age  Type of Travel  \
# Satisfaction
# neutral or dissatisfied  58708   58708          58708  58708           58708
# no answer                    6       6              6      6               6
# satisfied                44900   44900          44900  44900           44900
#
#                          Class  Flight Distance  Inflight wifi service  \
# Satisfaction
# neutral or dissatisfied  58708            58708                  58708
# no answer                    6                6                      6
# satisfied                44900            44900                  44900
#
#                          Departure/Arrival time convenient  \
# Satisfaction
# neutral or dissatisfied                              58708
# no answer                                                6
# satisfied                                            44900
#
#                          Ease of Online booking  ...  Seat comfort  \
# Satisfaction                                     ...
# neutral or dissatisfied                   58708  ...         58708
# no answer                                     6  ...             6
# satisfied                                 44900  ...         44900
#
#                          Inflight entertainment  On-board service  \
# Satisfaction
# neutral or dissatisfied                   58708             58708
# no answer                                     6                 6
# satisfied                                 44900             44900
#
#                          Leg room service  Baggage handling  Checkin service  \
# Satisfaction
# neutral or dissatisfied             58708             58708            58708
# no answer                               6                 6                6
# satisfied                           44900             44900            44900
#
#                          Inflight service  Cleanliness  \
# Satisfaction
# neutral or dissatisfied             58708        58708
# no answer                               6            6
# satisfied                           44900        44900
#
#                          Departure Delay in Minutes  Arrival Delay in Minutes
# Satisfaction
# neutral or dissatisfied                       58708                     58708
# no answer                                         6                         6
# satisfied                                     44900                     44900
#
# [3 rows x 23 columns]

# %%
##And how many customers are loyal customers.
df_new.groupby('Customer Type').count()
# Out:
#                       ID  Gender    Age  Type of Travel  Class  \
# Customer Type
# Disloyal Customer  18939   18939  18939           18939  18939
# Loyal Customer     84675   84675  84675           84675  84675
#
#                    Flight Distance  Inflight wifi service  \
# Customer Type
# Disloyal Customer            18939                  18939
# Loyal Customer               84675                  84675
#
#                    Departure/Arrival time convenient  Ease of Online booking  \
# Customer Type
# Disloyal Customer                              18939                   18939
# Loyal Customer                                 84675                   84675
#
#                    Gate location  ...  Inflight entertainment  \
# Customer Type                     ...
# Disloyal Customer          18939  ...                   18939
# Loyal Customer             84675  ...                   84675
#
#                    On-board service  Leg room service  Baggage handling  \
# Customer Type
# Disloyal Customer             18939             18939             18939
# Loyal Customer                84675             84675             84675
#
#                    Checkin service  Inflight service  Cleanliness  \
# Customer Type
# Disloyal Customer            18939             18939        18939
# Loyal Customer               84675             84675        84675
#
#                    Departure Delay in Minutes  Arrival Delay in Minutes  \
# Customer Type
# Disloyal Customer                       18939                     18939
# Loyal Customer                          84675                     84675
#
#                    Satisfaction
# Customer Type
# Disloyal Customer         18939
# Loyal Customer            84675
#
# [2 rows x 23 columns]

# %%
# %matplotlib inline

# %%
##Fin out the age groups
df['Age']
# Out:
# 0         13
# 1         25
# 2         26
# 3         25
# 4         61
#           ..
# 103919    34
# 103920    23
# 103921    17
# 103922    14
# 103923    42
# Name: Age, Length: 103924, dtype: int64

# %%
#Count the number of rows with different Ages
df.groupby('Age').count()
# Out:
#       ID  Gender  Customer Type  Type of Travel  Class  Flight Distance  \
# Age
# 7    562     562            562             562    562              562
# 8    640     640            640             640    640              640
# 9    692     692            692             692    692              692
# 10   683     683            683             683    683              683
# 11   678     678            678             678    678              678
# ..   ...     ...            ...             ...    ...              ...
# 77    87      87             87              87     87               87
# 78    33      33             33              33     33               33
# 79    42      42             42              42     42               42
# 80    78      78             78              78     78               78
# 85    17      17             17              17     17               17
#
#      Inflight wifi service  Departure/Arrival time convenient  \
# Age
# 7                      562                                562
# 8                      640                                640
# 9                      692                                692
# 10                     683                                683
# 11                     678                                678
# ..                     ...                                ...
# 77                      87                                 87
# 78                      33                                 33
# 79                      42                                 42
# 80                      78                                 78
# 85                      17                                 17
#
#      Ease of Online booking  Gate location  ...  Inflight entertainment  \
# Age                                         ...
# 7                       562            562  ...                     562
# 8                       640            640  ...                     640
# 9                       692            692  ...                     692
# 10                      683            683  ...                     683
# 11                      678            678  ...                     678
# ..                      ...            ...  ...                     ...
# 77                       87             87  ...                      87
# 78                       33             33  ...                      33
# 79                       42             42  ...                      42
# 80                       78             78  ...                      78
# 85                       17             17  ...                      17
#
#      On-board service  Leg room service  Baggage handling  Checkin service  \
# Age
# 7                 562               562               562              562
# 8                 640               640               640              640
# 9                 692               692               692              692
# 10                683               683               683              683
# 11                678               678               678              678
# ..                ...               ...               ...              ...
# 77                 87                87                87               87
# 78                 33                33                33               33
# 79                 42                42                42               42
# 80                 78                78                78               78
# 85                 17                17                17               17
#
#      Inflight service  Cleanliness  Departure Delay in Minutes  \
# Age
# 7                 562          562                         562
# 8                 640          640                         640
# 9                 692          692                         692
# 10                683          683                         683
# 11                678          678                         678
# ..                ...          ...                         ...
# 77                 87           87                          87
# 78                 33           33                          33
# 79                 42           42                          42
# 80                 78           78                          78
# 85                 17           17                          17
#
#      Arrival Delay in Minutes  Satisfaction
# Age
# 7                         562           562
# 8                         640           640
# 9                         692           692
# 10                        683           683
# 11                        678           678
# ..                        ...           ...
# 77                         87            87
# 78                         33            33
# 79                         42            42
# 80                         78            78
# 85                         17            17
#
# [75 rows x 23 columns]

# %%
#The avarage age
np.mean( df['Age'] )
# Out:
# 39.37903660367191

# %%
#Count the number of rows with different genders
df_new.groupby('Gender').count()
# Out:
#             ID  Customer Type    Age  Type of Travel  Class  Flight Distance  \
# Gender
# Diverse      7              7      7               7      7                7
# Female   52577          52577  52577           52577  52577            52577
# Male     51021          51021  51021           51021  51021            51021
# na           9              9      9               9      9                9
#
#          Inflight wifi service  Departure/Arrival time convenient  \
# Gender
# Diverse                      7                                  7
# Female                   52577                              52577
# Male                     51021                              51021
# na                           9                                  9
#
#          Ease of Online booking  Gate location  ...  Inflight entertainment  \
# Gender                                          ...
# Diverse                       7              7  ...                       7
# Female                    52577          52577  ...                   52577
# Male                      51021          51021  ...                   51021
# na                            9              9  ...                       9
#
#          On-board service  Leg room service  Baggage handling  \
# Gender
# Diverse                 7                 7                 7
# Female              52577             52577             52577
# Male                51021             51021             51021
# na                      9                 9                 9
#
#          Checkin service  Inflight service  Cleanliness  \
# Gender
# Diverse                7                 7            7
# Female             52577             52577        52577
# Male               51021             51021        51021
# na                     9                 9            9
#
#          Departure Delay in Minutes  Arrival Delay in Minutes  Satisfaction
# Gender
# Diverse                           7                         7             7
# Female                        52577                     52577         52577
# Male                          51021                     51021         51021
# na                                9                         9             9
#
# [4 rows x 23 columns]

# %%
#Check-out if there are duplicates
df.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103919    False
# 103920    False
# 103921    False
# 103922    False
# 103923    False
# Length: 103924, dtype: bool

# %%
##Find out Data outliers
